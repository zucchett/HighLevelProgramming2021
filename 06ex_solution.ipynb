# %%
import pandas as pd
import numpy as np
from numpy import random
import csv
import json
# %matplotlib inline

# %% [markdown]
# 1\. Perform the following operations on plain `txt` files:
#
# + create a list of integrer numbers and then save it to a text file named "data_int.txt". Run the `cat` command to print the content of the file.
# + create a matrix of 5x5 floats and then save it to a text file named "data_float.txt". Use the `cat` command to print the content of the file.
# + load the txt file of the previous point and convert it to a csv file by hand.

# %%
# create a list of integrer numbers and then save it to a text file 

integrer_numbers_list=np.random.randint(0, 100, 10)

with open ('data_int.txt','w') as data:
    data.write(str(integrer_numbers_list))
    
read_data_int=open("data_int.txt")
print(read_data_int.read())    

print('\n')

# create a matrix of 5x5 floats and then save it to a text file    
matrix_5x5 = np.random.rand(5,5)  

with open ('data_float.txt','w') as data:
    data.write(str(matrix_5x5))
    
read_data_float=open("data_float.txt")
print(read_data_float.read())


# load the txt file of the previous point and convert it to a csv file by hand

with open('data_float.txt', 'r') as old_file:
    stripped = (line.strip() for line in old_file)
    lines = (line.split(",") for line in stripped if line)
    with open('data_float.csv', 'w') as new_file: 
        writer = csv.writer(new_file) 
        writer.writerows(lines)
# Out:
# [41 47 35 66 85 66 36  4 86 42]
#
#
# [[0.86042349 0.80895693 0.44549651 0.2275948  0.43108201]
#  [0.12651277 0.62164457 0.79353314 0.84884562 0.31281951]
#  [0.73457687 0.90749014 0.2100192  0.10951942 0.14261807]
#  [0.7451676  0.68164316 0.4465282  0.40199336 0.17348646]
#  [0.39346025 0.36441637 0.2746734  0.22426201 0.66524042]]

# %% [markdown]
# 2\. Load the file *user_data.json*, which can be found at:
#
# - https://www.dropbox.com/s/sz5klcdpckc39hd/user_data.json
#
# and filter the data by the "CreditCardType" when it equals to "American Express". Than save the data to a new CSV file.

# %%
data = json.load(open('user_data.json'))
data_filtered = []
for i in range(0,len(data)):
    if data[i]['CreditCardType'] == 'American Express':
        data_filtered += [data[i]]
    
pd.DataFrame(data_filtered).to_csv('data_filtered.csv')

# %% [markdown]
# 3\. Load the file from this url:
#
# - https://www.dropbox.com/s/kgshemfgk22iy79/mushrooms_categorized.csv
#
# with Pandas.
#
# + explore and print the DataFrame
# + calculate, using `groupby()`, the average value of each feature, separately for each class
# + save the file in a JSON format.

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
newfile= 'mushrooms_categorized.csv'

csvdata = pd.read_csv(newfile)
display(csvdata)
average_value = csvdata.groupby(['class']).agg('mean')
display(average_value)

#save the file in a JSON format
average_value.to_json('average_value.json')
# Out:
# 'mushrooms_categorized.csv'
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# ...

# %% [markdown]
# 4\. Get the binary file named *credit_card.dat* from this address:
#
# - https://www.dropbox.com/s/8m0syw2tkul3dap/credit_card.dat
#
# and convert the data into the real credit card number, knowing that:
# - each line corresponds to a credit card number, which consists of 16 characters (which are numbers in the 0-9 range) divided in 4 blocks, with a whitespace between each block
# - each character is written using a 6 bit binary representation (including the whitespace)
# - the final 4 bits of each line are a padding used to determine the end of the line, and can be ignored
#
# *Hint*: convert the binary numbers to the decimal representation first, and then use the `chr()` function to convert the latter to a char

# %%
my_file = open("credit_card.dat", "r")
lines = my_file.readlines()

for line in lines: 
    number = ''
    for i in range(0, len(line), 6):
        if line[i:i+6]=="100000":
            number +=" "
        else:
            number+=chr(int(line[i:i+6], 2))
    print(number)
# Out:
# 7648 5673 3775 2271
#
# 3257 8247 3354 2266
#
# 2722 0001 4011 6652
#
# 0661 3063 3742 3150
#
# 0432 1608 1462 4742
#
# 5827 2027 8785 7303
#
# 5774 8528 2087 1117
#
# 8140 1210 6352 2845
#
# 5764 1133 7301 7100
#
# 6456 1737 4126 6726
#
# 1228 8631 7382 0000
#
# 7051 0160 5374 3166
#
# 0618 3587 1630 6376
#
# 1545 5454 7444 5636
#
# 6735 3116 3202 6834
#
# 7287 5011 1547 8413
#
# 7033 2607 3328 4200
#
# 2568 5244 1874 5024
#
# 1684 2253 7570 7118
#
# 0672 2576 0575 6631
#
# 6332 8353 8787 1340
#
# 1813 3361 1175 4211
#
# 2477 6450 8840 2368
#
# 5512 3505 2563 1326
#
# 3083 7882 0621 0025
#
# 4521 5148 8045 0334
#
# 7563 3654 8713 5787
#
# 8324 2664 0476 5561
#
# 0565 2504 7168 3510
#
# 5107 5507 1767 0738
#
# 2462 1821 2448 1443
#
# 2788 0638 6861 6554
#
# 5851 5873 5474 0547
#
# 0670 1004 4013 2655
#
# 5874 5506 3048 0806
#
# 2805 5401 8462 1260
#
# 5083 8406 6310 1862
#
# 1076 1445 3013 2266
#
# 8440 4804 4844 5277
#
# 4758 6141 0686 1387
#
# 7586 0675 0315 2568
#
# ...

# %% [markdown]
# 5\. **Optional**: load the remote file:
#
# - https://www.dropbox.com/s/aamg1apjhclecka/regression_generated.csv
#
# with Pandas and create a scatter plot with all possible combinations of the following features:
#
#   + features_1
#   + features_2
#   + features_3

# %%
import matplotlib.pyplot as plt

remote_file= 'regression_generated.csv'

dataframe = pd.read_csv(remote_file)
fig, ax = plt.subplots(figsize=(5, 5))
ax.scatter(dataframe['features_1'],dataframe['features_2'],color='orange')
ax.set_title('features_1 and features_2')
ax.set_ylabel('features_2')
ax.set_xlabel('features_1')
fig.tight_layout()

fig, ax = plt.subplots(figsize=(5, 5))
ax.scatter(dataframe['features_1'],dataframe['features_3'],color='green')
ax.set_title('features_1 and features_3')
ax.set_ylabel('features_3')
ax.set_xlabel('features_1')
fig.tight_layout()

fig, ax = plt.subplots(figsize=(5, 5))
ax.scatter(dataframe['features_2'],dataframe['features_3'],color='brown')
ax.set_title('features_2 and features_3')
ax.set_ylabel('features_3')
ax.set_xlabel('features_2')
fig.tight_layout()
