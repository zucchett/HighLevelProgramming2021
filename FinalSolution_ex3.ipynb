# %% [markdown]
# 1\. Write a function that converts numbers among the bin, dec, and hex representations (bin<->dec<->hex)

# %%
def convertion(x,y):
    if(y == "hex"):
        x_dec= int(x,16)
        x_bin=bin(x_dec)
        print("decimal: ",x_dec,"binary: " , x_bin)
    if (y== "dec"):
        x_hex=hex(x)
        x_bin=bin(x)
        print("hexadecimal: ",x_hex,"binary: " , x_bin)
    if (y=="bin"):
        x_dec=int(x,2)
        x_hex=hex(x_dec)
        print("hexadecimal: ",x_hex,"decimal: " , x_dec)
a= "0x23"
b= "hex"

print( "hex number: " , a)
convertion(a,b)

a= "0b0110"
b= "bin"

print( "bin number: " , a)
convertion(a,b)

a= 23
b= "dec"

print( "dec number: " , a)
convertion(a,b)
# Out:
# hex number:  0x23
# decimal:  35 binary:  0b100011
# bin number:  0b0110
# hexadecimal: 0x6 decimal 6
# dec number:  23
# hexadecimal:  0x17 binary:  0b10111

# %% [markdown]
# 2\. Write a function that converts a 32 bit word into a single precision floating point (i.e. interprets the various bits as sign, mantissa and exponent) and check its validity.

# %%
import math
def convertSingleP(a):
    print('%.32f' % (a)) # give >32 significant digits

a = 0.1 * 0.1 * 100 #expected = 1
convertSingleP(a)
          
b = 0.7
convertSingleP(b) #expected = 0.7

c= math.log(100,10) #expected = 2
convertSingleP(c) 

d = 0.2**3       #expected = 0.008
convertSingleP(d)
# Out:
# 1.00000000000000022204460492503131
# 0.69999999999999995559107901499374
# 2.00000000000000000000000000000000
# 0.00800000000000000190125692967058

# %% [markdown]
# 3\. Write a program to determine the underflow and overflow limits (within a factor of 2) for python on your computer.
#
# **Tip**: define two variables initialized to 1 and halve/double them for a sufficient amount of times to exceed the under/over-flow limits

# %%
number = 2000
undflow = 1
ovflow = 1

for i in range(number):
    undflow = undflow / 2
    ovflow  = ovflow  * 2
    print(i,"%1.2e"%undflow,"%1.2e"%ovflow)
    
#underflow limit is equal to 1.11e-308
#overflow limit is equal to 8.98e+307
# Out:
# 0 5.00e-01 2.00e+00
# 1 2.50e-01 4.00e+00
# 2 1.25e-01 8.00e+00
# 3 6.25e-02 1.60e+01
# 4 3.12e-02 3.20e+01
# 5 1.56e-02 6.40e+01
# 6 7.81e-03 1.28e+02
# 7 3.91e-03 2.56e+02
# 8 1.95e-03 5.12e+02
# 9 9.77e-04 1.02e+03
# 10 4.88e-04 2.05e+03
# 11 2.44e-04 4.10e+03
# 12 1.22e-04 8.19e+03
# 13 6.10e-05 1.64e+04
# 14 3.05e-05 3.28e+04
# 15 1.53e-05 6.55e+04
# 16 7.63e-06 1.31e+05
# 17 3.81e-06 2.62e+05
# 18 1.91e-06 5.24e+05
# 19 9.54e-07 1.05e+06
# 20 4.77e-07 2.10e+06
# 21 2.38e-07 4.19e+06
# 22 1.19e-07 8.39e+06
# 23 5.96e-08 1.68e+07
# 24 2.98e-08 3.36e+07
# 25 1.49e-08 6.71e+07
# 26 7.45e-09 1.34e+08
# 27 3.73e-09 2.68e+08
# 28 1.86e-09 5.37e+08
# 29 9.31e-10 1.07e+09
# 30 4.66e-10 2.15e+09
# 31 2.33e-10 4.29e+09
# 32 1.16e-10 8.59e+09
# 33 5.82e-11 1.72e+10
# 34 2.91e-11 3.44e+10
# 35 1.46e-11 6.87e+10
# 36 7.28e-12 1.37e+11
# 37 3.64e-12 2.75e+11
# 38 1.82e-12 5.50e+11
# 39 9.09e-13 1.10e+12
# 40 4.55e-13 2.20e+12
# 41 2.27e-13 4.40e+12
# 42 1.14e-13 8.80e+12
# ...

# %% [markdown]
# 4\. Write a program to determine the machine precision
#
# **Tip**: define a new variable by adding an increasingly smaller value (in the same way as the previous problem) and check when the addition starts to have no effect on the number

# %%
number = 30
var = 3 
fac = 2e-1
for i in range(number):
    var = var + fac
    fac = fac * 1e-1
    print(i,var)
#after the 14th point there is no change and effect
# Out:
# 0 3.2
# 1 3.22
# 2 3.222
# 3 3.2222
# 4 3.22222
# 5 3.222222
# 6 3.2222222
# 7 3.22222222
# 8 3.222222222
# 9 3.2222222222
# 10 3.22222222222
# 11 3.2222222222220003
# 12 3.2222222222222
# 13 3.22222222222222
# 14 3.2222222222222223
# 15 3.2222222222222223
# 16 3.2222222222222223
# 17 3.2222222222222223
# 18 3.2222222222222223
# 19 3.2222222222222223
# 20 3.2222222222222223
# 21 3.2222222222222223
# 22 3.2222222222222223
# 23 3.2222222222222223
# 24 3.2222222222222223
# 25 3.2222222222222223
# 26 3.2222222222222223
# 27 3.2222222222222223
# 28 3.2222222222222223
# 29 3.2222222222222223

# %% [markdown]
# 5\. Write a function that takes in input three parameters $a$, $b$ and $c$ and prints out the two solutions to the quadratic equation $ax^2+bx+c=0$ using the standard formula:
# $$
# x=\frac{-b\pm\sqrt{b^2-4ac}}{2a}
# $$
#
# (a) use the program to compute the solution for $a=0.001$, $b=1000$ and $c=0.001$
#
# (b) re-express the standard solution formula by multiplying the numerator and the denominator by $-b\mp\sqrt{b^2-4ac}$ and again find the solution for $a=0.001$, $b=1000$ and $c=0.001$. How does it compare with what has been previously obtained, and why?
#
# (c) write a function that computes the roots of a quadratic equation accurately in all cases

# %%
def computequadraticAll(a, b, c):
    d = b**2 - 4 * a * c
    sqrt_val = math.sqrt(abs(d))
    
    if d > 0:
        solution1 =(-b + sqrt_val)/(2 * a)
        solution2 =(-b - sqrt_val)/(2 * a)
        print(solution1, solution2)
    elif d == 0:
        print(-b / (2*a))
    else:  # d<0
        print("No real Solutions")

def computequadratic(a,b,c):
    d = b**2 - 4 * a * c
    sqrt_val = math.sqrt(abs(d))
    solution1= (b + sqrt_val)/(2*a)
    solution2= (b - sqrt_val)/(2*a)
    print("First Solutions:")
    print(solution1,solution2)
    x = (b + math.sqrt(b**2-(4*a*c)))
    y = (b - math.sqrt(b**2-(4*a*c)))
    solution1_new = (y * (b + sqrt_val))/(2*a * y)
    solution2_new = (x * (b - sqrt_val))/(2*a * x)
    print("Second Solutions:")
    print(solution1_new ,solution2_new)
a=0.001
b=1000
c=0.001
computequadratic(a,b,c)
print("Solutions of Part C")
computequadraticAll(a,b,c)
# Out:
# First Solutions:
# 999999.999999 9.999894245993346e-07
# Second Solutions:
# 999999.9999990001 9.999894245993346e-07
# Solutions of Part C
# -9.999894245993346e-07 -999999.999999

# %% [markdown]
# 6\. Write a program that implements the function $f(x)=x(x−1)$
#
# (a) Calculate the derivative of the function at the point $x = 1$ using the derivative definition:
#
# $$
# \frac{{\rm d}f}{{\rm d}x} = \lim_{\delta\to0} \frac{f(x+\delta)-f(x)}{\delta}
# $$
#
# with $\delta = 10^{−2}$. Calculate the true value of the same derivative analytically and compare it with the answer your program gives. The two will not agree perfectly. Why?
#
# (b) Repeat the calculation for $\delta = 10^{−4}, 10^{−6}, 10^{−8}, 10^{−10}, 10^{−12}$ and $10^{−14}$. How does the accuracy scales with $\delta$?

# %%
from sympy import *
import numpy as np
def function(x):
    return (x*(x-1))

def derivative(x,S):
    return (function(x+S)-function(x))/(S)

x = Symbol('x')
f = x*(x-1)
f_p = f.diff(x)
f_p = lambdify(x, f_p)
print("Analytically : ", f_p(1))

x=1
S=10**(-2)
print(derivative(x,S))
S=10**(-4)
print(derivative(x,S))
S=10**(-6)
print(derivative(x,S))
S=10**(-8)
print(derivative(x,S))
S=10**(-10)
print(derivative(x,S))
S=10**(-12)
print(derivative(x,S))
S=10**(-14)
print(derivative(x,S))

#analytically solution is equal to 1. But when we calculate on the derivative function defination we are calculate to 1.01 
#because numbers representative of binary on the program so we can reach to the accurate numbers and because of the S=10**-2
#we can close to the zero but not exactly zero

# S get smaller result close to the true solution but it cant reach the exactly solution
# Out:
# Analytically :  1
# 1.010000000000001
# 1.0000999999998899
# 1.0000009999177333
# 1.0000000039225287
# 1.000000082840371
# 1.0000889005833413
# 0.9992007221626509

# %% [markdown]
# 7\. Consider the integral of the semicircle of radius 1:
# $$
# I=\int_{-1}^{1} \sqrt(1-x^2) {\rm d}x
# $$
# which is known to be $I=\frac{\pi}{2}=1.57079632679...$.
#
# Alternatively we can use the Riemann definition of the integral:
# $$
# I=\lim_{N\to\infty} \sum_{k=1}^{N} h y_k
# $$
#
# with $h=2/N$ the width of each of the $N$ slices the domain is divided into and where
# $y_k$ is the value of the function at the $k-$th slice.
#
# (a) Write a program to compute the integral with $N=100$. How does the result compare to the true value?
#
# (b) How much can $N$ be increased if the computation needs to be run in less than a second? What is the gain in running it for 1 minute?

# %%
import math
import time

def Integral(a, b, N):
    h = (b - a) / N
    delta = (a - b) / N
    k = [b + delta*(i + .5) for i in range(N)]
    return sum([h * math.sqrt(1 - x**2) for x in k])

N = 100
I = Integral(-1, 1, N)
print("Result of Integral:" , I)
print("Result of pi/2:", math.pi/2)
# Out:
# Result of Integral: 1.5712827762297958
# Result of pi/2: 1.5707963267948966

# %%
executionTime = 0
N = 100
while executionTime < 1:
    start = time.time()
    Integral(-1, 1, N)
    executionTime = time.time() - start
    print("N:", N, "Execution Time:", executionTime)
    N *= 10

#Maximum number of computations is N =1000000 for the program to work under 1 second.
# Out:
# N: 100 Execution Time: 0.0009953975677490234
# N: 1000 Execution Time: 0.0
# N: 10000 Execution Time: 0.0049860477447509766
# N: 100000 Execution Time: 0.04095149040222168
# N: 1000000 Execution Time: 0.4696810245513916
# N: 10000000 Execution Time: 4.687481880187988
