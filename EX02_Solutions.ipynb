# %% [markdown]
# 1. Write the following expressions using the list comprehension

# %%
# 1
ans = []
for i in range(3):
    for j in range(4):
        ans.append((i, j))
print(ans)

# 2
ans = map(lambda x: x * x, filter(lambda x: x % 2 == 1, range(10)))
print(list(ans))
# Out:
# [(0, 0), (0, 1), (0, 2), (0, 3), (1, 0), (1, 1), (1, 2), (1, 3), (2, 0), (2, 1), (2, 2), (2, 3)]
# [1, 9, 25, 49, 81]

# %%
# 1
ans = [(i,j) for i in range(3) for j in range(4)]
print(ans)
# 2
ans = [x**2 for x in range(10) if x % 2 == 1]
print(ans)
# Out:
# [(0, 0), (0, 1), (0, 2), (0, 3), (1, 0), (1, 1), (1, 2), (1, 3), (2, 0), (2, 1), (2, 2), (2, 3)]
# [1, 9, 25, 49, 81]

# %% [markdown]
# 2\. Convert the function $f$ into a function that doesn't use global variables and that does not modify the original list

# %%
x = 5
def f(alist):
    for i in range(x):
         alist.append(i)
    return alist

alist = [1,2,3]
ans = f(alist)
print(ans)
print(alist) # alist has been changed!
# Out:
# [1, 2, 3, 0, 1, 2, 3, 4]
# [1, 2, 3, 0, 1, 2, 3, 4]

# %%
x = 5
def f(alist):
    alist = []
    for i in range(x):
        alist.append(i)
    return alist

alist = [1,2,3]
ans = f(alist)
print(ans)
print(alist) # alist has not been changed!
# Out:
# [0, 1, 2, 3, 4]
# [1, 2, 3]

# %% [markdown]
# 3\. Write a `decorator` hello that makes every wrapped function print “Hello!”, i.e. something like:
#
# ```python
# @hello
# def square(x):
#     return x*x
# ```

# %%
def decorator(func):
    def wrapper():
        func()
        print ("Hello!")
    return wrapper

def myFunction():
    print("Hello!")
    
myFunction = decorator(myFunction)

# %% [markdown]
# 4\. Write the factorial function in two different ways, so that it a) does and b) does not use recursion.

# %%
def factWithRec(x):
    if x==0 or x==1:
        return 1
    else:
        result = 1
        for i in range(1,x+1):
            result = result*i
        print("Factorial With Recursion: ",result)

def factWithoutRec(x):
    result = 1
    for i in range(1,x+1):
        result = result*i
    print("Factorial Without Recursion: ",result)
    
factWithRec(4)        
factWithoutRec(4)
# Out:
# Factorial With recursion:  24
# Factorial Without recursion:  24

# %% [markdown]
# 5\. Use HOFs (zip in particular) to compute the weight of a circle, a disk and a sphere, assuming different radii and different densities:
#
# ```python
# densities = {"Al" : [0.5, 1, 2], "Fe" : [3, 4, 5], "Pb" : [15, 20, 30]}
# radii = [1, 2, 3]
# ```
#
# where the entries of the dictionary's values are the linear, superficial and volumetric densities of the materials respectively.
#
# Subsequently, define a list using a comprehension with three lambda functions that compute the circumference, the area and the volume for a given radius.

# %%
import math
def findWeight(radii,densities):
    #for i in range(len(radii)):
        volume = 4/3*math.pi*(radii/2)**3
        weight = volume*densities
        return weight

densities = {"Al" : [0.5, 1, 2], "Fe" : [3, 4, 5], "Pb" : [15, 20, 30]}
radii = [1, 2, 3]
for i in densities:
    for k in range(len(densities[i])):
        for j in range(len(radii)):
            weightList.append(findWeight(radii[j],densities[i][k]))
            densityList.append(densities[i][k])
            radiiList.append(radii[j])
print("density radii weight")            
for x,y,z in zip(densityList,radiiList,weightList):
    print(x,y,z)
# Out:
# density radii weight
# 0.5 1 0.2617993877991494
# 0.5 2 2.0943951023931953
# 0.5 3 7.068583470577034
# 1 1 0.5235987755982988
# 1 2 4.1887902047863905
# 1 3 14.137166941154067
# 2 1 1.0471975511965976
# 2 2 8.377580409572781
# 2 3 28.274333882308134
# 3 1 1.5707963267948966
# 3 2 12.566370614359172
# 3 3 42.411500823462205
# 4 1 2.0943951023931953
# 4 2 16.755160819145562
# 4 3 56.54866776461627
# 5 1 2.617993877991494
# 5 2 20.94395102393195
# 5 3 70.68583470577033
# 15 1 7.853981633974482
# 15 2 62.831853071795855
# 15 3 212.057504117311
# 20 1 10.471975511965976
# 20 2 83.7758040957278
# 20 3 282.74333882308133
# 30 1 15.707963267948964
# 30 2 125.66370614359171
# 30 3 424.115008234622
# 5 2 56.54866776461627
# 5 3 2.617993877991494
# 15 1 20.94395102393195
# 15 2 70.68583470577033
# 15 3 7.853981633974482
# 20 1 62.831853071795855
# 20 2 212.057504117311
# 20 3 10.471975511965976
# 30 1 83.7758040957278
# 30 2 282.74333882308133
# 30 3 15.707963267948964
# 0.5 1 125.66370614359171
# 0.5 2 424.115008234622
# 0.5 3 0.2617993877991494
# 1 1 2.0943951023931953
# 1 2 7.068583470577034
# 1 3 0.5235987755982988
# 2 1 4.1887902047863905
# 2 2 14.137166941154067
# 2 3 1.0471975511965976
# 3 1 8.377580409572781
# 3 2 28.274333882308134
# 3 3 1.5707963267948966
# 4 1 12.566370614359172
# 4 2 42.411500823462205
# 4 3 2.0943951023931953
# 5 1 16.755160819145562
# 5 2 56.54866776461627
# 5 3 2.617993877991494
# 15 1 20.94395102393195
# 15 2 70.68583470577033
# 15 3 7.853981633974482
# 20 1 62.831853071795855
# 20 2 212.057504117311
# 20 3 10.471975511965976
# 30 1 83.7758040957278
# 30 2 282.74333882308133
# 30 3 15.707963267948964
# 0.5 1 125.66370614359171
# 0.5 2 424.115008234622
# 0.5 3 0.2617993877991494
# 1 1 2.0943951023931953
# 1 2 7.068583470577034
# 1 3 0.5235987755982988
# 2 1 4.1887902047863905
# 2 2 14.137166941154067
# 2 3 1.0471975511965976
# 3 1 8.377580409572781
# 3 2 28.274333882308134
# 3 3 1.5707963267948966
# 4 1 12.566370614359172
# 4 2 42.411500823462205
# 4 3 2.0943951023931953
# 5 1 16.755160819145562
# 5 2 56.54866776461627
# 5 3 2.617993877991494
# 15 1 20.94395102393195
# 15 2 70.68583470577033
# 15 3 7.853981633974482
# 20 1 62.831853071795855
# 20 2 212.057504117311
# 20 3 10.471975511965976
# 30 1 83.7758040957278
# 30 2 282.74333882308133
# 30 3 15.707963267948964

# %% [markdown]
# 6\. Edit the class defintion to add an instance attribute of `is_hungry = True` to the Dog class. Then add a method called `eat()` which changes the value of `is_hungry` to `False` when called. Figure out the best way to instantiate the dog objects and to feed the dogs, e.g. call the `eat()` method for all instances. Finally, print “My dogs are hungry.” or “My dogs are not hungry.” if all of them have `is_hungry = True` or `False`, respectively. The final output should look like this:
#
# `I have 3 dogs.
# Tom is 6.
# Fletcher is 7.
# Larry is 9.
# And they're all mammals, of course.
# My dogs are not hungry.
# `
#
# ```python
# # Parent class
# class Dog:
#
#     # Class attribute
#     species = 'mammal'
#
#     # Initializer / Instance attributes
#     def __init__(self, name, age):
#         self.name = name
#         self.age = age
#
#     # instance method
#     def description(self):
#         return "{} is {} years old".format(self.name, self.age)
#
#     # instance method
#     def speak(self, sound):
#         return "{} says {}".format(self.name, sound)
#
# # Child class (inherits from Dog class)
# class RussellTerrier(Dog):
#     def run(self, speed):
#         return "{} runs {}".format(self.name, speed)
#
# # Child class (inherits from Dog class)
# class Bulldog(Dog):
#     def run(self, speed):
#         return "{} runs {}".format(self.name, speed)
# ```

# %%
# Parent class
class Dog:
    
    number_of_dogs= 0

    # Class attribute
    species = 'mammal'

    # Initializer / Instance attributes
    def __init__(self, name, age,is_hungry,number_of_dogs):
        self.name = name
        self.age = age
        self.is_hungry = True
        self.number_of_dogs += 1

    # instance method
    def description(self):
        return "{} is {} years old".format(self.name, self.age)

    # instance method
    def speak(self, sound):
        return "{} says {}".format(self.name, sound)

# Child class (inherits from Dog class)
class RussellTerrier(Dog):
    def run(self, speed):
        return "{} runs {}".format(self.name, speed)

# Child class (inherits from Dog class)
class Bulldog(Dog):
    def run(self, speed):
        return "{} runs {}".format(self.name, speed)
   
    
    # instance method eat()
    def eat(self, is_hungry):
        self.is_hungry = False
        
dog1 = Dog("Tom",6,"mammals","true")
dog2 = Dog("Fletcher",7,"mammals","true")
dog3 = Dog("Larry",9,"mammals","true")

print(str(Dog.number_of_dogs))
# Out:
# 0
